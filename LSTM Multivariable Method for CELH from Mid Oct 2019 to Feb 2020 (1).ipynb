# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv(r"C:\\Users\\Owner\Desktop\celh_feb20.csv")
data
# Out:
#             Date  Open  High   Low  Close  Adj Close  Volume
# 0     2008-08-08  2.00  2.00  2.00   2.00       2.00    5500
# 1     2008-08-11  2.00  2.00  1.80   2.00       2.00   78600
# 2     2008-08-12  2.00  2.00  1.80   1.80       1.80   39200
# 3     2008-08-13  1.80  1.80  1.80   1.80       1.80   15000
# 4     2008-08-14  1.80  1.80  1.80   1.80       1.80   24300
# ...          ...   ...   ...   ...    ...        ...     ...
# 2903  2020-02-21  6.38  7.10  6.32   6.40       6.40  839300
# 2904  2020-02-24  6.31  6.32  6.05   6.19       6.19  342700
# 2905  2020-02-25  6.22  6.31  5.94   5.98       5.98  399300
# 2906  2020-02-26  5.99  6.47  5.95   6.44       6.44  412100
# 2907  2020-02-27  6.36  6.37  6.04   6.22       6.22  388100
#
# [2908 rows x 7 columns]

# %%
data_training = data[data['Date'] < '2019-10-31'].copy()
data_testing = data[data['Date'] >= '2019-10-31'].copy()

# %%
data_training = data_training.drop(['Date', 'Adj Close'], axis = 1)

# %%
data_training.shape
# Out:
# (2827, 5)

# %%
scaler = MinMaxScaler()
data_training = scaler.fit_transform(data_training)
data_training
# Out:
# array([[0.13357401, 0.13357401, 0.17448405, 0.13754647, 0.00209508],
#        [0.13357401, 0.13357401, 0.15572233, 0.13754647, 0.02994058],
#        [0.13357401, 0.13357401, 0.15572233, 0.12267658, 0.0149322 ],
#        ...,
#        [0.24548736, 0.24765343, 0.31144465, 0.25130112, 0.08730763],
#        [0.24404332, 0.24548736, 0.31050657, 0.2527881 , 0.05911931],
#        [0.24765343, 0.24765343, 0.30956848, 0.2527881 , 0.03656864]])

# %%
x_train = []
y_train = []

for i in range(100, data_training.shape[0]):
    x_train.append(data_training[i-100:i])
    y_train.append(data_training[i, 0])

x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

regressor.add(LSTM(units = 70, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 5)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 90, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 100, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 110, activation = 'relu'))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 70)           21280
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 70)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 90)           57960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 90)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 100)          76400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 110)               92840
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 110)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 111
# =================================================================
# Total params: 248,591
# Trainable params: 248,591
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(x_train, y_train, epochs = 125, batch_size = 32)
# Out:
# Epoch 1/125
# 86/86 [==============================] - 26s 300ms/step - loss: 0.0062
# Epoch 2/125
# 86/86 [==============================] - 26s 304ms/step - loss: 0.0024
# Epoch 3/125
# 86/86 [==============================] - 28s 322ms/step - loss: 0.0021
# Epoch 4/125
# 86/86 [==============================] - 28s 324ms/step - loss: 0.0016
# Epoch 5/125
# 86/86 [==============================] - 28s 326ms/step - loss: 0.0014
# Epoch 6/125
# 86/86 [==============================] - 28s 330ms/step - loss: 0.0016
# Epoch 7/125
# 86/86 [==============================] - 28s 327ms/step - loss: 0.0013
# Epoch 8/125
# 86/86 [==============================] - 28s 330ms/step - loss: 0.0012
# Epoch 9/125
# 86/86 [==============================] - 28s 331ms/step - loss: 0.0012
# Epoch 10/125
# 86/86 [==============================] - 28s 325ms/step - loss: 0.0011
# Epoch 11/125
# 86/86 [==============================] - 28s 326ms/step - loss: 0.0011
# Epoch 12/125
# 86/86 [==============================] - 28s 331ms/step - loss: 9.9119e-04
# Epoch 13/125
# 86/86 [==============================] - 28s 328ms/step - loss: 0.0012
# Epoch 14/125
# 86/86 [==============================] - 28s 328ms/step - loss: 0.0011
# Epoch 15/125
# 86/86 [==============================] - 29s 334ms/step - loss: 9.6391e-04
# Epoch 16/125
# 86/86 [==============================] - 29s 334ms/step - loss: 7.6588e-04
# Epoch 17/125
# 86/86 [==============================] - 29s 332ms/step - loss: 8.1025e-04
# Epoch 18/125
# 86/86 [==============================] - 29s 333ms/step - loss: 7.0058e-04
# Epoch 19/125
# 86/86 [==============================] - 29s 332ms/step - loss: 7.0141e-04
# Epoch 20/125
# 86/86 [==============================] - 28s 325ms/step - loss: 8.5895e-04
# Epoch 21/125
# 86/86 [==============================] - 27s 316ms/step - loss: 7.3700e-04
# Epoch 22/125
# 86/86 [==============================] - 30s 344ms/step - loss: 8.0522e-04
# Epoch 23/125
# 86/86 [==============================] - 29s 337ms/step - loss: 6.6746e-04
# Epoch 24/125
# 86/86 [==============================] - 30s 347ms/step - loss: 7.5428e-04
# Epoch 25/125
# 86/86 [==============================] - 30s 343ms/step - loss: 8.0583e-04
# Epoch 26/125
# 86/86 [==============================] - 30s 343ms/step - loss: 6.1601e-04
# Epoch 27/125
# 86/86 [==============================] - 30s 354ms/step - loss: 6.4340e-04
# Epoch 28/125
# 86/86 [==============================] - 29s 334ms/step - loss: 7.6805e-04
# Epoch 29/125
# 86/86 [==============================] - 27s 315ms/step - loss: 7.8248e-04
# Epoch 30/125
# 86/86 [==============================] - 27s 317ms/step - loss: 7.2309e-04
# Epoch 31/125
# 86/86 [==============================] - 27s 316ms/step - loss: 6.8473e-04
# Epoch 32/125
# 86/86 [==============================] - 28s 321ms/step - loss: 7.2704e-04
# Epoch 33/125
# 86/86 [==============================] - 28s 323ms/step - loss: 6.1980e-04
# Epoch 34/125
# 86/86 [==============================] - 28s 325ms/step - loss: 7.4681e-04
# Epoch 35/125
# 86/86 [==============================] - 28s 322ms/step - loss: 5.5169e-04
# Epoch 36/125
# 86/86 [==============================] - 29s 333ms/step - loss: 5.8362e-04
# Epoch 37/125
# 86/86 [==============================] - 28s 328ms/step - loss: 5.8644e-04
# Epoch 38/125
# 86/86 [==============================] - 29s 338ms/step - loss: 5.1582e-04
# Epoch 39/125
# 86/86 [==============================] - 29s 333ms/step - loss: 5.2011e-04
# Epoch 40/125
# 86/86 [==============================] - 29s 332ms/step - loss: 5.3831e-04
# Epoch 41/125
# 86/86 [==============================] - 29s 339ms/step - loss: 5.2306e-04
# Epoch 42/125
# 86/86 [==============================] - 29s 332ms/step - loss: 4.9012e-04
# Epoch 43/125
# 86/86 [==============================] - 29s 334ms/step - loss: 4.6002e-04
# Epoch 44/125
# 86/86 [==============================] - 29s 335ms/step - loss: 4.7756e-04
# Epoch 45/125
# 86/86 [==============================] - 30s 348ms/step - loss: 5.0564e-04
# Epoch 46/125
# 86/86 [==============================] - 30s 346ms/step - loss: 5.4670e-04
# Epoch 47/125
# 86/86 [==============================] - 34s 398ms/step - loss: 4.8723e-04
# Epoch 48/125
# 86/86 [==============================] - 30s 354ms/step - loss: 4.6784e-04
# Epoch 49/125
# 86/86 [==============================] - 26s 306ms/step - loss: 4.8278e-04
# Epoch 50/125
# 86/86 [==============================] - 26s 302ms/step - loss: 5.3425e-04
# Epoch 51/125
# 86/86 [==============================] - 26s 303ms/step - loss: 5.0745e-04
# Epoch 52/125
# 86/86 [==============================] - 26s 300ms/step - loss: 5.0235e-04
# Epoch 53/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.2632e-04
# Epoch 54/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.5704e-04
# Epoch 55/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.9534e-04
# Epoch 56/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.6548e-04
# Epoch 57/125
# 86/86 [==============================] - 27s 317ms/step - loss: 4.3290e-04
# Epoch 58/125
# 86/86 [==============================] - 26s 302ms/step - loss: 4.4586e-04
# Epoch 59/125
# 86/86 [==============================] - 26s 302ms/step - loss: 4.6280e-04
# Epoch 60/125
# 86/86 [==============================] - 26s 304ms/step - loss: 4.4697e-04
# Epoch 61/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.4808e-04
# Epoch 62/125
# 86/86 [==============================] - 27s 309ms/step - loss: 4.8297e-04
# Epoch 63/125
# 86/86 [==============================] - 26s 305ms/step - loss: 4.5171e-04
# Epoch 64/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.4096e-04
# Epoch 65/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.9457e-04
# Epoch 66/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.1292e-04
# Epoch 67/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.4190e-04
# Epoch 68/125
# 86/86 [==============================] - 26s 299ms/step - loss: 3.9720e-04
# Epoch 69/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.3813e-04
# Epoch 70/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.5298e-04
# Epoch 71/125
# 86/86 [==============================] - 27s 309ms/step - loss: 4.6052e-04
# Epoch 72/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.4504e-04
# Epoch 73/125
# 86/86 [==============================] - 26s 297ms/step - loss: 4.0485e-04
# Epoch 74/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.8138e-04
# Epoch 75/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.7080e-04
# Epoch 76/125
# 86/86 [==============================] - 26s 297ms/step - loss: 4.6327e-04
# Epoch 77/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.9586e-04
# Epoch 78/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.2303e-04
# Epoch 79/125
# 86/86 [==============================] - 26s 297ms/step - loss: 4.4147e-04
# Epoch 80/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.7723e-04
# Epoch 81/125
# 86/86 [==============================] - 26s 297ms/step - loss: 4.6192e-04
# Epoch 82/125
# 86/86 [==============================] - 25s 296ms/step - loss: 4.3983e-04
# Epoch 83/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.8712e-04
# Epoch 84/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.5010e-04
# Epoch 85/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.1062e-04
# Epoch 86/125
# 86/86 [==============================] - 26s 306ms/step - loss: 4.1624e-04
# Epoch 87/125
# 86/86 [==============================] - 26s 303ms/step - loss: 4.1342e-04
# Epoch 88/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.9549e-04
# Epoch 89/125
# 86/86 [==============================] - 26s 298ms/step - loss: 4.4304e-04
# Epoch 90/125
# 86/86 [==============================] - 26s 300ms/step - loss: 4.0018e-04
# Epoch 91/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.5067e-04
# Epoch 92/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.9094e-04
# Epoch 93/125
# 86/86 [==============================] - 26s 301ms/step - loss: 3.7790e-04
# Epoch 94/125
# 86/86 [==============================] - 26s 300ms/step - loss: 3.6930e-04
# Epoch 95/125
# 86/86 [==============================] - 26s 299ms/step - loss: 4.1890e-04
# Epoch 96/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.6442e-04
# Epoch 97/125
# 86/86 [==============================] - 26s 301ms/step - loss: 3.7524e-04
# Epoch 98/125
# 86/86 [==============================] - 26s 299ms/step - loss: 3.7299e-04
# Epoch 99/125
# 86/86 [==============================] - 26s 300ms/step - loss: 3.8110e-04
# Epoch 100/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.9766e-04
# Epoch 101/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.6793e-04
# Epoch 102/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.4839e-04
# Epoch 103/125
# 86/86 [==============================] - 26s 297ms/step - loss: 4.0520e-04
# Epoch 104/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.7572e-04
# Epoch 105/125
# 86/86 [==============================] - 25s 296ms/step - loss: 3.8677e-04
# Epoch 106/125
# 86/86 [==============================] - 26s 299ms/step - loss: 3.6386e-04
# Epoch 107/125
# 86/86 [==============================] - 25s 296ms/step - loss: 3.7118e-04
# Epoch 108/125
# 86/86 [==============================] - 26s 304ms/step - loss: 3.5362e-04
# Epoch 109/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.8871e-04
# Epoch 110/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.7108e-04
# Epoch 111/125
# 86/86 [==============================] - 25s 296ms/step - loss: 3.2222e-04
# Epoch 112/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.7723e-04
# Epoch 113/125
# 86/86 [==============================] - 26s 300ms/step - loss: 3.5337e-04
# Epoch 114/125
# 86/86 [==============================] - 26s 297ms/step - loss: 3.6935e-04
# Epoch 115/125
# 86/86 [==============================] - 26s 307ms/step - loss: 3.9964e-04
# Epoch 116/125
# 86/86 [==============================] - 26s 305ms/step - loss: 3.8604e-04
# Epoch 117/125
# 86/86 [==============================] - 26s 302ms/step - loss: 3.7177e-04
# Epoch 118/125
# 86/86 [==============================] - 26s 298ms/step - loss: 3.7901e-04
# Epoch 119/125
# 86/86 [==============================] - 3066s 36s/step - loss: 3.7133e-04
# Epoch 120/125
# 86/86 [==============================] - 28s 321ms/step - loss: 3.6352e-04
# Epoch 121/125
# 86/86 [==============================] - 28s 326ms/step - loss: 3.8107e-04
# Epoch 122/125
# 86/86 [==============================] - 25s 290ms/step - loss: 3.1711e-04
# Epoch 123/125
# 86/86 [==============================] - 25s 288ms/step - loss: 3.6116e-04
# Epoch 124/125
# 86/86 [==============================] - 25s 288ms/step - loss: 2.9281e-04
# Epoch 125/125
# 86/86 [==============================] - 27s 311ms/step - loss: 3.5557e-04

# %%
data_testing.head()
# Out:
#             Date  Open  High   Low  Close  Adj Close  Volume
# 2827  2019-10-31  3.53  3.53  3.43   3.52       3.52  118100
# 2828  2019-11-01  3.50  3.65  3.49   3.60       3.60  128100
# 2829  2019-11-04  3.62  3.68  3.53   3.65       3.65  248200
# 2830  2019-11-05  3.68  3.70  3.55   3.56       3.56  153900
# 2831  2019-11-06  3.56  3.73  3.47   3.70       3.70  230500

# %%
past_30_days = data_testing.tail(30)

# %%
df = past_30_days.append(data_testing, ignore_index = True)
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#    Open  High   Low  Close   Volume
# 0  4.85  4.89  4.78   4.83   194700
# 1  4.77  5.07  4.73   5.05   613000
# 2  5.10  5.30  5.07   5.24   695600
# 3  5.29  5.76  5.25   5.74  1113200
# 4  5.76  6.10  5.66   5.77  1255600

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.33935018, 0.34223827, 0.43527205, 0.34795539, 0.07416578],
#        [0.33357401, 0.35523466, 0.43058161, 0.36431227, 0.23350602],
#        [0.35740072, 0.37184116, 0.46247655, 0.37843866, 0.26497029],
#        [0.37111913, 0.40505415, 0.4793621 , 0.41561338, 0.42404388],
#        [0.40505415, 0.42960289, 0.51782364, 0.41784387, 0.47828737],
#        [0.40577617, 0.42815884, 0.50844278, 0.43494424, 0.2604373 ],
#        [0.42815884, 0.44909747, 0.55065666, 0.4401487 , 0.41436843],
#        [0.42238267, 0.43032491, 0.53846154, 0.43271375, 0.140675  ],
#        [0.42238267, 0.43610108, 0.51594747, 0.41635688, 0.20147036],
#        [0.40288809, 0.40288809, 0.49437148, 0.40446097, 0.19053786],
#        [0.39061372, 0.39855596, 0.49906191, 0.40297398, 0.0526817 ],
#        [0.38700361, 0.3898917 , 0.47748593, 0.39033457, 0.14875057],
#        [0.37833935, 0.39855596, 0.49249531, 0.40594796, 0.0874981 ],
#        [0.39566787, 0.39927798, 0.49718574, 0.40148699, 0.17290111],
#        [0.39350181, 0.40938628, 0.50750469, 0.41189591, 0.16852049],
#        [0.40072202, 0.4101083 , 0.51688555, 0.41635688, 0.07915587],
#        [0.40433213, 0.40577617, 0.51313321, 0.41189591, 0.06506171],
#        [0.4       , 0.41516245, 0.51500938, 0.42379182, 0.13343745],
#        [0.41588448, 0.42454874, 0.53377111, 0.42750929, 0.10524912],
#        [0.41805054, 0.42960289, 0.53564728, 0.43717472, 0.05626238],
#        [0.42382671, 0.42888087, 0.53846154, 0.42825279, 0.04277769],
#        [0.4166065 , 0.42960289, 0.53658537, 0.44089219, 0.05919549],
#        [0.43249097, 0.4433213 , 0.55347092, 0.44981413, 0.11717202],
#        [0.43971119, 0.45487365, 0.56378987, 0.44758364, 0.14608411],
#        [0.433213  , 0.45631769, 0.56378987, 0.466171  , 0.10524912],
#        [0.44981949, 0.50180505, 0.57973734, 0.46468401, 0.31970897],
#        [0.44476534, 0.44548736, 0.55440901, 0.44907063, 0.13054243],
#        [0.43826715, 0.44476534, 0.54409006, 0.43345725, 0.1521027 ],
#        [0.42166065, 0.45631769, 0.54502814, 0.46765799, 0.15697852],
#        [0.44837545, 0.44909747, 0.55347092, 0.45130112, 0.14783636],
#        [0.24404332, 0.24404332, 0.30863039, 0.25055762, 0.04498705],
#        [0.24187726, 0.25270758, 0.31425891, 0.25650558, 0.04879628],
#        [0.25054152, 0.25487365, 0.31801126, 0.26022305, 0.09454518],
#        [0.25487365, 0.25631769, 0.31988743, 0.2535316 , 0.0586241 ],
#        [0.24620939, 0.25848375, 0.31238274, 0.26394052, 0.08780283],
#        [0.25920578, 0.28375451, 0.33395872, 0.28475836, 0.25384733],
#        [0.27870036, 0.28303249, 0.35272045, 0.28252788, 0.10182081],
#        [0.27725632, 0.28736462, 0.35834897, 0.28996283, 0.06388085],
#        [0.28519856, 0.28519856, 0.34615385, 0.28178439, 0.07088984],
#        [0.27364621, 0.2765343 , 0.34333959, 0.27137546, 0.06620448],
#        [0.26425993, 0.27436823, 0.34333959, 0.27360595, 0.06075728],
#        [0.26714801, 0.27292419, 0.34146341, 0.27509294, 0.10361115],
#        [0.26137184, 0.26714801, 0.34052533, 0.27360595, 0.03923511],
#        [0.26425993, 0.28519856, 0.34052533, 0.28698885, 0.13503733],
#        [0.27942238, 0.30974729, 0.34615385, 0.30185874, 0.47097364],
#        [0.3133574 , 0.32129964, 0.3902439 , 0.32862454, 0.22162121],
#        [0.32129964, 0.34223827, 0.4043152 , 0.32118959, 0.21800244],
#        [0.31407942, 0.34223827, 0.40900563, 0.33680297, 0.25982782],
#        [0.32635379, 0.34296029, 0.42120075, 0.34944238, 0.16528265],
#        [0.34584838, 0.35956679, 0.44465291, 0.35687732, 0.1963279 ],
#        [0.34151625, 0.34584838, 0.42401501, 0.34944238, 0.08208898],
#        [0.33646209, 0.34223827, 0.42870544, 0.34275093, 0.10989639],
#        [0.32851986, 0.32851986, 0.4043152 , 0.333829  , 0.14844583],
#        [0.32563177, 0.32851986, 0.40900563, 0.32936803, 0.12166692],
#        [0.32057762, 0.32851986, 0.40150094, 0.3197026 , 0.12372391],
#        [0.31407942, 0.33212996, 0.40806754, 0.33903346, 0.11420082],
#        [0.33140794, 0.35018051, 0.41932458, 0.35836431, 0.26184672],
#        [0.34945848, 0.34945848, 0.42213884, 0.33754647, 0.11709584],
#        [0.32707581, 0.32924188, 0.40994371, 0.33085502, 0.09325004],
#        [0.32129964, 0.32202166, 0.40619137, 0.32862454, 0.08205089],
#        [0.32057762, 0.32057762, 0.39868668, 0.32416357, 0.06772817],
#        [0.3198556 , 0.3198556 , 0.39868668, 0.31895911, 0.09824013],
#        [0.30974729, 0.31480144, 0.39118199, 0.31747212, 0.08692671],
#        [0.30974729, 0.31119134, 0.37711069, 0.30855019, 0.11618162],
#        [0.29891697, 0.31191336, 0.38180113, 0.31301115, 0.11621972],
#        [0.30469314, 0.31191336, 0.38649156, 0.30855019, 0.27003657],
#        [0.30036101, 0.32418773, 0.38742964, 0.32936803, 0.14181777],
#        [0.32129964, 0.32924188, 0.3902439 , 0.33085502, 0.09260247],
#        [0.32057762, 0.33140794, 0.41463415, 0.333829  , 0.08365077],
#        [0.32707581, 0.33212996, 0.42213884, 0.34052045, 0.0790416 ],
#        [0.3299639 , 0.34151625, 0.4249531 , 0.34944238, 0.09020265],
#        [0.34079422, 0.34079422, 0.42682927, 0.34795539, 0.14494134],
#        [0.33790614, 0.34079422, 0.42870544, 0.34200743, 0.10898217],
#        [0.32851986, 0.32851986, 0.41181989, 0.33457249, 0.11122962],
#        [0.3198556 , 0.32563177, 0.40806754, 0.32490706, 0.10216364],
#        [0.31407942, 0.31407942, 0.37242026, 0.30557621, 0.45067043],
#        [0.29747292, 0.31046931, 0.38649156, 0.31524164, 0.13473259],
#        [0.31046931, 0.33140794, 0.39681051, 0.33754647, 0.16208289],
#        [0.32851986, 0.34223827, 0.41463415, 0.33234201, 0.09107877],
#        [0.32274368, 0.34079422, 0.41463415, 0.3464684 , 0.13035197],
#        [0.33574007, 0.34079422, 0.4315197 , 0.3464684 , 0.07336584],
#        [0.33935018, 0.34223827, 0.43527205, 0.34795539, 0.07416578],
#        [0.33357401, 0.35523466, 0.43058161, 0.36431227, 0.23350602],
#        [0.35740072, 0.37184116, 0.46247655, 0.37843866, 0.26497029],
#        [0.37111913, 0.40505415, 0.4793621 , 0.41561338, 0.42404388],
#        [0.40505415, 0.42960289, 0.51782364, 0.41784387, 0.47828737],
#        [0.40577617, 0.42815884, 0.50844278, 0.43494424, 0.2604373 ],
#        [0.42815884, 0.44909747, 0.55065666, 0.4401487 , 0.41436843],
#        [0.42238267, 0.43032491, 0.53846154, 0.43271375, 0.140675  ],
#        [0.42238267, 0.43610108, 0.51594747, 0.41635688, 0.20147036],
#        [0.40288809, 0.40288809, 0.49437148, 0.40446097, 0.19053786],
#        [0.39061372, 0.39855596, 0.49906191, 0.40297398, 0.0526817 ],
#        [0.38700361, 0.3898917 , 0.47748593, 0.39033457, 0.14875057],
#        [0.37833935, 0.39855596, 0.49249531, 0.40594796, 0.0874981 ],
#        [0.39566787, 0.39927798, 0.49718574, 0.40148699, 0.17290111],
#        [0.39350181, 0.40938628, 0.50750469, 0.41189591, 0.16852049],
#        [0.40072202, 0.4101083 , 0.51688555, 0.41635688, 0.07915587],
#        [0.40433213, 0.40577617, 0.51313321, 0.41189591, 0.06506171],
#        [0.4       , 0.41516245, 0.51500938, 0.42379182, 0.13343745],
#        [0.41588448, 0.42454874, 0.53377111, 0.42750929, 0.10524912],
#        [0.41805054, 0.42960289, 0.53564728, 0.43717472, 0.05626238],
#        [0.42382671, 0.42888087, 0.53846154, 0.42825279, 0.04277769],
#        [0.4166065 , 0.42960289, 0.53658537, 0.44089219, 0.05919549],
#        [0.43249097, 0.4433213 , 0.55347092, 0.44981413, 0.11717202],
#        [0.43971119, 0.45487365, 0.56378987, 0.44758364, 0.14608411],
#        [0.433213  , 0.45631769, 0.56378987, 0.466171  , 0.10524912],
#        [0.44981949, 0.50180505, 0.57973734, 0.46468401, 0.31970897],
#        [0.44476534, 0.44548736, 0.55440901, 0.44907063, 0.13054243],
#        [0.43826715, 0.44476534, 0.54409006, 0.43345725, 0.1521027 ],
#        [0.42166065, 0.45631769, 0.54502814, 0.46765799, 0.15697852],
#        [0.44837545, 0.44909747, 0.55347092, 0.45130112, 0.14783636]])

# %%
x_test = []
y_test = []

for i in range(30, inputs.shape[0]):
    x_test.append(inputs[i-30:i])
    y_test.append(inputs[i,0])
    
x_test = np.array(x_test)
y_test = np.array(y_test)
x_test.shape, y_test.shape
# Out:
# ((81, 30, 5), (81,))

# %%
x_test.shape
# Out:
# (81, 30, 5)

# %%
y_pred = regressor.predict(x_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 5) for input Tensor("lstm_input:0", shape=(None, 100, 5), dtype=float32), but it was called on an input with incompatible shape (None, 30, 5).

# %%
scaler.scale_
# Out:
# array([7.22021661e-02, 7.22021661e-02, 9.38086304e-02, 7.43494424e-02,
#        3.80923358e-07])

# %%
scale = 1 / 7.22021661e-02
scale
# Out:
# 13.849999993282749

# %%
y_pred = y_pred * scale 
y_test = y_test * scale

# %%
y_pred.shape
# Out:
# (81, 1)

# %%
y_pred[0:]
# Out:
# array([[5.764749 ],
#        [5.124092 ],
#        [4.477453 ],
#        [3.979822 ],
#        [3.6969202],
#        [3.6084168],
#        [3.7845721],
#        [3.9038172],
#        [3.8378785],
#        [3.7177117],
#        [3.608734 ],
#        [3.5657136],
#        [3.5726852],
#        [3.5748336],
#        [3.669398 ],
#        [3.7938507],
#        [4.3199434],
#        [4.336525 ],
#        [4.294254 ],
#        [4.365259 ],
#        [4.592122 ],
#        [4.48794  ],
#        [4.346517 ],
#        [4.203339 ],
#        [4.147842 ],
#        [4.0937853],
#        [4.1998124],
#        [4.509525 ],
#        [4.437219 ],
#        [4.2605963],
#        [4.1299167],
#        [4.0888295],
#        [4.060378 ],
#        [4.0090623],
#        [3.9271548],
#        [3.9349082],
#        [3.9469433],
#        [4.1428976],
#        [4.164159 ],
#        [4.2298565],
#        [4.3278255],
#        [4.43798  ],
#        [4.427628 ],
#        [4.3692636],
#        [4.239617 ],
#        [4.1308975],
#        [3.9799826],
#        [4.0243025],
#        [4.24327  ],
#        [4.310508 ],
#        [4.335206 ],
#        [4.3924823],
#        [4.4299817],
#        [4.5667663],
#        [4.8891325],
#        [5.392091 ],
#        [5.534269 ],
#        [5.4305477],
#        [5.6969285],
#        [5.591559 ],
#        [5.345384 ],
#        [5.09658  ],
#        [5.041468 ],
#        [4.8990464],
#        [5.0550885],
#        [5.1077967],
#        [5.2257795],
#        [5.260523 ],
#        [5.1943836],
#        [5.383974 ],
#        [5.54338  ],
#        [5.5466967],
#        [5.4654946],
#        [5.5826225],
#        [5.8463435],
#        [5.8465533],
#        [5.863022 ],
#        [6.2100725],
#        [5.8417387],
#        [5.495076 ],
#        [5.8867307]], dtype=float32)

# %%
y_test.shape
# Out:
# (81,)

# %%
y_test[0:]
# Out:
# array([3.38, 3.35, 3.47, 3.53, 3.41, 3.59, 3.86, 3.84, 3.95, 3.79, 3.66,
#        3.7 , 3.62, 3.66, 3.87, 4.34, 4.45, 4.35, 4.52, 4.79, 4.73, 4.66,
#        4.55, 4.51, 4.44, 4.35, 4.59, 4.84, 4.53, 4.45, 4.44, 4.43, 4.29,
#        4.29, 4.14, 4.22, 4.16, 4.45, 4.44, 4.53, 4.57, 4.72, 4.68, 4.55,
#        4.43, 4.35, 4.12, 4.3 , 4.55, 4.47, 4.65, 4.7 , 4.62, 4.95, 5.14,
#        5.61, 5.62, 5.93, 5.85, 5.85, 5.58, 5.41, 5.36, 5.24, 5.48, 5.45,
#        5.55, 5.6 , 5.54, 5.76, 5.79, 5.87, 5.77, 5.99, 6.09, 6.  , 6.23,
#        6.16, 6.07, 5.84, 6.21])

# %%
plt.figure(figsize = (14,5))
plt.plot(y_test, color = 'red', label = 'Real CELH Stock Price')
plt.plot(y_pred, color = 'blue', label = 'Predicted CELH Stock price')
plt.title('CELH Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('CELH Stock Price')
plt.legend()
plt.show()
