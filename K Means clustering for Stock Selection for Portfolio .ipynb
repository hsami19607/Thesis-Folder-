# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
pwd
# Out:
# 'C:\\Users\\Owner'

# %%
df = pd.read_csv('C:\\Users\\Owner\Desktop\Ratiosecond.csv')
df
# Out:
#     ast_turn  oprt_mrgn
# 0       0.74     0.0764
# 1       1.52     0.0210
# 2       0.69     0.2717
# 3       0.35     0.1539
# 4       0.98     0.0597
# ..       ...        ...
# 59      0.70    -2.7626
# 60      1.03     0.1371
# 61      0.09    -3.3984
# 62      1.33     0.1469
# 63      0.49     0.0978
#
# [64 rows x 2 columns]

# %%
plt.scatter(df['ast_turn'], df['oprt_mrgn'])
plt.xlabel('Asset Turnover Ratio')
plt.ylabel('Operating Margin Ratio')
plt.show()

# %%
x = df.copy()
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
clusters = x.copy()
clusters['cluster_pred'] = kmeans.fit_predict(x)

# %%
plt.scatter(clusters['ast_turn'], clusters['oprt_mrgn'], c = clusters['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Asset Turnover Ratio')
plt.ylabel('Operating Margin Ratio')
plt.show()

# %%
from sklearn import preprocessing 
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-0.19192115,  0.49766879],
#        [ 0.7585455 ,  0.45724594],
#        [-0.2528485 ,  0.64017031],
#        [-0.66715448,  0.55421701],
#        [ 0.10053013,  0.48548357],
#        [-0.26503397,  0.47110937],
#        [ 0.62450534,  0.52473897],
#        [-0.64278354,  0.45002236],
#        [ 1.47748823,  0.54414778],
#        [-0.64278354,  0.45002236],
#        [ 0.6001344 ,  0.51124037],
#        [-0.47218696,  0.71984857],
#        [-0.41125961,  0.52590642],
#        [ 0.42953782,  0.49927403],
#        [-0.43563055,  0.5751581 ],
#        [ 1.63589934,  0.4716931 ],
#        [-0.75245277,  0.91225845],
#        [-1.04490405, -3.09420114],
#        [-0.30159038,  0.46038345],
#        [-0.21629209,  0.48796439],
#        [ 1.62371387,  0.45483808],
#        [-0.20410662,  0.56136763],
#        [-0.47218696,  0.22594548],
#        [-0.38688867,  0.30876126],
#        [-0.64278354, -0.49378567],
#        [-0.33814679, -0.37346565],
#        [-0.99616217, -1.71989699],
# ...

# %%
weights = []

for i in range(1, 30):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    weights.append(kmeans.inertia_)
weights
# Out:
# [127.99999999999997,
#  67.89634021698075,
#  26.553597172325823,
#  16.298762240537698,
#  10.775496546060888,
#  7.5539047058820525,
#  4.963538709538433,
#  4.236525357052777,
#  3.560112799008194,
#  3.1469042394934705,
#  2.6222560049126717,
#  2.111856327879104,
#  1.8533757366510961,
#  1.6520414363073488,
#  1.3080614743129564,
#  1.0513462621892908,
#  0.9444515010085011,
#  0.786435731081851,
#  0.6781069078508907,
#  0.6028955493494549,
#  0.5198173731955812,
#  0.46758585317191614,
#  0.42508347102878263,
#  0.3867039628704998,
#  0.34357340429706384,
#  0.3042063978316983,
#  0.28334688106756556,
#  0.2689327064537024,
#  0.22781774098191998]

# %%
plt.plot(range(1, 30), weights)
plt.xlabel('Number of Clsuters')
plt.ylabel('Weights')
plt.show()

# %%
kmeans_new = KMeans(4)
kmeans.fit(x_scaled)
cluster_new = x.copy()
cluster_new['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
cluster_new
# Out:
#     ast_turn  oprt_mrgn  cluster_pred
# 0       0.74     0.0764             1
# 1       1.52     0.0210             3
# 2       0.69     0.2717             1
# 3       0.35     0.1539             1
# 4       0.98     0.0597             1
# ..       ...        ...           ...
# 59      0.70    -2.7626             0
# 60      1.03     0.1371             1
# 61      0.09    -3.3984             0
# 62      1.33     0.1469             3
# 63      0.49     0.0978             1
#
# [64 rows x 3 columns]

# %%
plt.scatter(cluster_new['ast_turn'], cluster_new['oprt_mrgn'], c = cluster_new['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Asset Turnover Ratio')
plt.ylabel('Oper')
