# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
pwd
# Out:
# 'C:\\Users\\Owner'

# %%
df = pd.read_csv('C:\\Users\\Owner\Desktop\stockratios20.csv')
df
# Out:
#        eps  current_Rat
# 0    1.470         4.67
# 1    0.150         1.20
# 2   17.600         3.31
# 3    3.070         1.65
# 4    6.120         3.92
# 5    3.860         1.22
# 6    4.800         5.17
# 7    3.200         2.41
# 8    2.230         1.75
# 9    6.200         2.53
# 10   8.780         5.51
# 11   0.520         1.63
# 12   1.860         4.98
# 13   2.650         1.38
# 14   3.590         1.38
# 15   1.770         2.66
# 16   6.030         1.54
# 17  11.560         1.36
# 18   4.270         1.19
# 19   0.080         3.16
# 20   1.100         1.86
# 21   0.240         1.15
# 22   1.620        17.87
# 23   1.150         4.79
# 24   1.580         2.56
# 25   0.890        10.77
# 26   4.310         3.81
# 27   3.610         3.49
# 28   0.670         2.62
# 29   0.770         2.24
# 30   3.000         1.56
# 31   5.550         1.31
# 32   6.960         2.92
# 33   1.970        10.09
# 34   4.030         1.51
# 35   0.350         1.68
# 36   0.130         4.99
# ...

# %%
plt.scatter(df['eps'], df['current_Rat'])
plt.xlabel('Earnings per Share')
plt.ylabel('Current Ratio')
plt.show()

# %%
x = df.copy()
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
clusters = x.copy()
clusters['cluster_pred'] = kmeans.fit_predict(x)

# %%
plt.scatter(clusters['eps'], clusters['current_Rat'], c = clusters['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Earnings Per Share')
plt.ylabel('Current Ratio')
plt.show()

# %%
from sklearn import preprocessing 
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-0.59056055,  0.45113042],
#        [-0.96525976, -0.68399893],
#        [ 3.98815026,  0.00623823],
#        [-0.13637969, -0.53679195],
#        [ 0.72940258,  0.20578546],
#        [ 0.08787211, -0.6774564 ],
#        [ 0.35470337,  0.61469373],
#        [-0.09947749, -0.28817572],
#        [-0.37482464, -0.50407929],
#        [ 0.75211162, -0.24892053],
#        [ 1.48447826,  0.72591678],
#        [-0.86023043, -0.54333448],
#        [-0.47985396,  0.55253967],
#        [-0.25560216, -0.62511614],
#        [ 0.01122909, -0.62511614],
#        [-0.50540164, -0.20639407],
#        [ 0.70385491, -0.57277588],
#        [ 2.27361751, -0.63165867],
#        [ 0.20425596, -0.68727019],
#        [-0.98513017, -0.04283076],
#        [-0.69558987, -0.46809536],
#        [-0.93971208, -0.70035526],
#        [-0.54798109,  4.76920174],
#        [-0.68139672,  0.49038562],
#        [-0.55933561, -0.23910673],
#        [-0.75520111,  2.44660277],
#        [ 0.21561048,  0.16980154],
# ...

# %%
weights = []

for i in range(1, 30):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    weights.append(kmeans.inertia_)
weights
# Out:
# [86.0,
#  52.96822065169036,
#  26.788949042467184,
#  18.361944030537977,
#  14.42664317978273,
#  10.326056851382242,
#  7.599641067824552,
#  5.201798127808306,
#  4.007618856611258,
#  2.907710272215433,
#  2.308600702673166,
#  1.8724552157274574,
#  1.4781034861123992,
#  1.2751702433697836,
#  1.0127888910038594,
#  0.8383376287247334,
#  0.7216840463077002,
#  0.6068523615375725,
#  0.5650279061249935,
#  0.4713330807599895,
#  0.40031146512492977,
#  0.33885815810970893,
#  0.2712715414260858,
#  0.23986230113988238,
#  0.20830653823885684,
#  0.17405314112551382,
#  0.15378903843850317,
#  0.11742323056131167,
#  0.10034003674309679]

# %%
plt.plot(range(1, 30), weights)
plt.xlabel('Number of Clsuters')
plt.ylabel('Weights')
plt.show()

# %%
kmeans_new = KMeans(4)
kmeans.fit(x_scaled)
cluster_new = x.copy()
cluster_new['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
cluster_new
# Out:
#        eps  current_Rat  cluster_pred
# 0    1.470         4.67             0
# 1    0.150         1.20             0
# 2   17.600         3.31             1
# 3    3.070         1.65             0
# 4    6.120         3.92             2
# 5    3.860         1.22             2
# 6    4.800         5.17             2
# 7    3.200         2.41             0
# 8    2.230         1.75             0
# 9    6.200         2.53             2
# 10   8.780         5.51             2
# 11   0.520         1.63             0
# 12   1.860         4.98             0
# 13   2.650         1.38             0
# 14   3.590         1.38             2
# 15   1.770         2.66             0
# 16   6.030         1.54             2
# 17  11.560         1.36             1
# 18   4.270         1.19             2
# 19   0.080         3.16             0
# 20   1.100         1.86             0
# 21   0.240         1.15             0
# 22   1.620        17.87             3
# 23   1.150         4.79             0
# ...

# %%
plt.scatter(cluster_new['eps'], cluster_new['current_Rat'], c = cluster_new['cluster_pred'], cmap = 'rainbow')
plt.xlabel('Earnings Per Share')
plt.ylabel('Current Ratio')
plt.show()
