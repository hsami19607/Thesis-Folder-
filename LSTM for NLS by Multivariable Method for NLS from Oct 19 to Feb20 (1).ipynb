# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler

# %%
pwd
# Out:
# 'C:\\Users\\Owner'

# %%
data = pd.read_csv(r"C:\\Users\\Owner\Desktop\nls_feb20.csv")
data
# Out:
#             Date  Open  High   Low  Close  Adj Close   Volume
# 0     2008-08-08  5.78  6.20  5.75   6.00       6.00   555300
# 1     2008-08-11  5.67  6.06  5.67   5.90       5.90   406100
# 2     2008-08-12  5.87  5.99  5.62   5.80       5.80   344500
# 3     2008-08-13  5.69  5.86  5.31   5.55       5.55   568600
# 4     2008-08-14  5.53  5.79  5.44   5.59       5.59   390400
# ...          ...   ...   ...   ...    ...        ...      ...
# 2903  2020-02-21  3.79  3.81  3.33   3.47       3.47   612500
# 2904  2020-02-24  3.30  3.38  3.15   3.16       3.16   682700
# 2905  2020-02-25  3.80  4.00  3.12   3.31       3.31  1581900
# 2906  2020-02-26  3.40  3.45  3.15   3.15       3.15   660300
# 2907  2020-02-27  3.15  3.15  2.70   2.76       2.76   777100
#
# [2908 rows x 7 columns]

# %%
data_training = data[data['Date'] < '2019-10-31'].copy()
data_testing = data[data['Date'] >= '2019-10-31'].copy()

# %%
data_training = data_training.drop(['Date', 'Adj Close'], axis = 1)

# %%
data_training.shape
# Out:
# (2827, 5)

# %%
scaler = MinMaxScaler()
data_training = scaler.fit_transform(data_training)
data_training
# Out:
# array([[0.21842862, 0.23086369, 0.22203603, 0.22553018, 0.07805769],
#        [0.21390373, 0.22513303, 0.21868454, 0.22145188, 0.05677441],
#        [0.2221308 , 0.2222677 , 0.21658986, 0.21737357, 0.04798722],
#        ...,
#        [0.05676676, 0.06221858, 0.05655635, 0.05709625, 0.1487832 ],
#        [0.05841217, 0.05648792, 0.05655635, 0.05628059, 0.07845711],
#        [0.05676676, 0.05607859, 0.05236699, 0.05179445, 0.07757268]])

# %%
x_train = []
y_train = []

for i in range(100, data_training.shape[0]):
    x_train.append(data_training[i-100: i])
    y_train.append(data_training[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape
# Out:
# (2727, 100, 5)

# %%
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

regressor.add(LSTM(units = 70, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 5)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 90, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 110, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 120, activation = 'relu'))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %%
regressor.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 70)           21280
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100, 70)           0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 90)           57960
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 90)           0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 110)          88440
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 100, 110)          0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 120)               110880
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 278,681
# Trainable params: 278,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(x_train, y_train, epochs = 125, batch_size = 32)
# Out:
# Epoch 1/125
# 86/86 [==============================] - 26s 301ms/step - loss: 0.0191
# Epoch 2/125
# 86/86 [==============================] - 27s 320ms/step - loss: 0.0036
# Epoch 3/125
# 86/86 [==============================] - 26s 306ms/step - loss: 0.0036
# Epoch 4/125
# 86/86 [==============================] - 26s 303ms/step - loss: 0.0029
# Epoch 5/125
# 86/86 [==============================] - 24s 283ms/step - loss: 0.0029
# Epoch 6/125
# 86/86 [==============================] - 26s 297ms/step - loss: 0.0027
# Epoch 7/125
# 86/86 [==============================] - 26s 301ms/step - loss: 0.0028
# Epoch 8/125
# 86/86 [==============================] - 27s 312ms/step - loss: 0.0025
# Epoch 9/125
# 86/86 [==============================] - 26s 297ms/step - loss: 0.0025
# Epoch 10/125
# 86/86 [==============================] - 25s 293ms/step - loss: 0.0024
# Epoch 11/125
# 86/86 [==============================] - 25s 294ms/step - loss: 0.0024
# Epoch 12/125
# 86/86 [==============================] - 26s 300ms/step - loss: 0.0022
# Epoch 13/125
# 86/86 [==============================] - 25s 290ms/step - loss: 0.0020
# Epoch 14/125
# 86/86 [==============================] - 26s 306ms/step - loss: 0.0020
# Epoch 15/125
# 86/86 [==============================] - 27s 312ms/step - loss: 0.0023
# Epoch 16/125
# 86/86 [==============================] - 26s 298ms/step - loss: 0.0020
# Epoch 17/125
# 86/86 [==============================] - 24s 280ms/step - loss: 0.0018
# Epoch 18/125
# 86/86 [==============================] - 24s 276ms/step - loss: 0.0018
# Epoch 19/125
# 86/86 [==============================] - 24s 278ms/step - loss: 0.0016
# Epoch 20/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0014
# Epoch 21/125
# 86/86 [==============================] - 24s 279ms/step - loss: 0.0018
# Epoch 22/125
# 86/86 [==============================] - 24s 278ms/step - loss: 0.0014
# Epoch 23/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0014
# Epoch 24/125
# 86/86 [==============================] - 24s 276ms/step - loss: 0.0016
# Epoch 25/125
# 86/86 [==============================] - 24s 276ms/step - loss: 0.00140s - loss: 0.001
# Epoch 26/125
# 86/86 [==============================] - 24s 277ms/step - loss: 0.0015
# Epoch 27/125
# 86/86 [==============================] - 24s 284ms/step - loss: 0.0015
# Epoch 28/125
# 86/86 [==============================] - 24s 274ms/step - loss: 0.0013
# Epoch 29/125
# 86/86 [==============================] - 24s 279ms/step - loss: 0.0015
# Epoch 30/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0014
# Epoch 31/125
# 86/86 [==============================] - 24s 274ms/step - loss: 0.0012
# Epoch 32/125
# 86/86 [==============================] - 24s 282ms/step - loss: 0.0013
# Epoch 33/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0012
# Epoch 34/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0013
# Epoch 35/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0012
# Epoch 36/125
# 86/86 [==============================] - 24s 277ms/step - loss: 0.0012
# Epoch 37/125
# 86/86 [==============================] - 24s 275ms/step - loss: 0.0012
# Epoch 38/125
# 86/86 [==============================] - 24s 274ms/step - loss: 0.0011
# Epoch 39/125
# 86/86 [==============================] - 24s 275ms/step - loss: 7.3598e-04
# Epoch 112/125
# 86/86 [==============================] - 23s 273ms/step - loss: 6.9814e-040s - loss: 6.9814e-0
# Epoch 113/125
# 86/86 [==============================] - 23s 273ms/step - loss: 6.9387e-04
# Epoch 114/125
# 86/86 [==============================] - 23s 273ms/step - loss: 7.1253e-04
# Epoch 115/125
# 86/86 [==============================] - 23s 272ms/step - loss: 7.0613e-04
# Epoch 116/125
# 86/86 [==============================] - 24s 276ms/step - loss: 7.5763e-04
# Epoch 117/125
# 86/86 [==============================] - 23s 273ms/step - loss: 6.5941e-04
# Epoch 118/125
# 86/86 [==============================] - 25s 296ms/step - loss: 7.4692e-04
# Epoch 119/125
# 86/86 [==============================] - 24s 282ms/step - loss: 7.2829e-04
# Epoch 120/125
# 86/86 [==============================] - 24s 282ms/step - loss: 7.9249e-04
# Epoch 121/125
# 86/86 [==============================] - 25s 288ms/step - loss: 6.9971e-04
# Epoch 122/125
# 86/86 [==============================] - 24s 281ms/step - loss: 7.4587e-04
# Epoch 123/125
# 86/86 [==============================] - 26s 306ms/step - loss: 6.5370e-04
# Epoch 124/125
# 86/86 [==============================] - 27s 314ms/step - loss: 7.1480e-04
# Epoch 125/125
# 86/86 [==============================] - 25s 294ms/step - loss: 7.9566e-04

# %%
data_testing.head()
# Out:
#             Date  Open  High   Low  Close  Adj Close  Volume
# 2827  2019-10-31  1.75  1.76  1.64   1.65       1.65  343500
# 2828  2019-11-01  1.65  1.80  1.64   1.70       1.70  479000
# 2829  2019-11-04  1.70  1.77  1.69   1.71       1.71  269800
# 2830  2019-11-05  1.70  1.74  1.65   1.68       1.68  438000
# 2831  2019-11-06  1.69  1.72  1.64   1.67       1.67  266400

# %%
past_60_days = data_testing.tail(60)

# %%
df = past_60_days.append(data_testing, ignore_index = True)
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#    Open  High   Low  Close   Volume
# 0  1.46  1.46  1.33   1.36   747200
# 1  1.37  1.44  1.32   1.43   689300
# 2  1.40  1.69  1.39   1.61  1468300
# 3  1.64  1.86  1.59   1.80  1205100
# 4  1.86  1.86  1.64   1.72   437300

# %%
inputs = scaler.transform(df)
inputs
# Out:
# array([[0.04072398, 0.03683995, 0.03686636, 0.0362969 , 0.10543208],
#        [0.0370218 , 0.03602129, 0.03644742, 0.03915171, 0.09717269],
#        [0.03825586, 0.0462546 , 0.03937997, 0.04649266, 0.20829648],
#        [0.04812834, 0.05321326, 0.04775869, 0.05424144, 0.17075119],
#        [0.05717811, 0.05321326, 0.04985337, 0.05097879, 0.06122507],
#        [0.05183052, 0.05075727, 0.05236699, 0.05301794, 0.04513423],
#        [0.05388729, 0.05648792, 0.05529954, 0.05954323, 0.14748509],
#        [0.06005759, 0.06099059, 0.05571848, 0.06158238, 0.13983909],
#        [0.06046894, 0.06017192, 0.05781315, 0.05668842, 0.07995492],
#        [0.0555327 , 0.05485059, 0.05278592, 0.05220228, 0.08220878],
#        [0.05306458, 0.04952927, 0.04859656, 0.04893964, 0.08397763],
#        [0.0493624 , 0.0462546 , 0.04733976, 0.04893964, 0.09770049],
#        [0.05059646, 0.05689726, 0.05152912, 0.05831974, 0.17577245],
#        [0.05882353, 0.05525993, 0.05613741, 0.0550571 , 0.05720236],
#        [0.05594405, 0.05198526, 0.0536238 , 0.05179445, 0.04798722],
#        [0.05183052, 0.0523946 , 0.05278592, 0.05342577, 0.05392143],
#        [0.05347593, 0.05157593, 0.0548806 , 0.05301794, 0.01733189],
#        [0.05265323, 0.0499386 , 0.05111018, 0.04893964, 0.04872899],
#        [0.04853969, 0.04666394, 0.04943444, 0.04893964, 0.03904311],
#        [0.05018511, 0.0474826 , 0.05027231, 0.04934747, 0.02971385],
#        [0.0493624 , 0.05075727, 0.05069124, 0.05220228, 0.06790106],
#        [0.05470999, 0.05198526, 0.05446167, 0.05464927, 0.0464894 ],
#        [0.05676676, 0.05280393, 0.0536238 , 0.05342577, 0.03917149],
#        [0.05347593, 0.05607859, 0.05446167, 0.05831974, 0.08202334],
#        [0.05882353, 0.06590258, 0.06074571, 0.06810767, 0.15316253],
#        [0.06951871, 0.06876791, 0.06577294, 0.06973899, 0.16187841],
#        [0.07034142, 0.09496521, 0.07038123, 0.09584013, 0.53597615],
#        [0.09214315, 0.11011052, 0.09049016, 0.11215334, 0.39358364],
#        [0.12052653, 0.12689316, 0.1085044 , 0.11908646, 0.41392542],
#        [0.123406  , 0.13385182, 0.11939673, 0.13254486, 0.28508459],
#        [0.13286713, 0.13999181, 0.13405949, 0.13539967, 0.13861231],
#        [0.13656931, 0.13671715, 0.12107248, 0.12601958, 0.21802516],
#        [0.12093788, 0.1273025 , 0.12400503, 0.12479608, 0.07647428],
#        [0.12422871, 0.12648383, 0.11101801, 0.12438825, 0.16883969],
#        [0.12464006, 0.1473598 , 0.12609971, 0.1411093 , 0.22495792],
#        [0.14479637, 0.14121981, 0.13154587, 0.12724307, 0.09454794],
#        [0.12916495, 0.13426115, 0.12526183, 0.1223491 , 0.09955493],
#        [0.12176059, 0.12975849, 0.11939673, 0.12153344, 0.10005421],
#        [0.12258329, 0.12443717, 0.12442396, 0.12520392, 0.02516333],
#        [0.12875359, 0.1273025 , 0.12735651, 0.12479608, 0.05346495],
#        [0.12422871, 0.12116251, 0.11185589, 0.11256117, 0.10110981],
#        [0.11229946, 0.10888252, 0.10138249, 0.11052202, 0.06733046],
#        [0.10983134, 0.10724519, 0.09635526, 0.09380098, 0.09534678],
#        [0.09378856, 0.09455587, 0.09300377, 0.09094617, 0.0727654 ],
#        [0.10407239, 0.13098649, 0.10473398, 0.11704731, 0.27479958],
#        [0.11929247, 0.12320917, 0.11353163, 0.11052202, 0.09152378],
#        [0.11147675, 0.10888252, 0.11018014, 0.11011419, 0.05452056],
#        [0.1110654 , 0.10765452, 0.10180142, 0.0995106 , 0.04521982],
#        [0.09995886, 0.10397053, 0.10180142, 0.10032626, 0.05380731],
#        [0.10201563, 0.10274253, 0.1026393 , 0.0995106 , 0.04094034],
#        [0.09995886, 0.0986492 , 0.10180142, 0.0995106 , 0.03151123],
#        [0.09995886, 0.10151453, 0.1026393 , 0.10358891, 0.03479216],
#        [0.10407239, 0.1035612 , 0.10222036, 0.10318108, 0.02703204],
#        [0.10530645, 0.10151453, 0.1026393 , 0.10032626, 0.01835896],
#        [0.10612916, 0.13548915, 0.10892333, 0.13743883, 0.20923797],
#        [0.13656931, 0.13303316, 0.12065354, 0.1223491 , 0.08621723],
#        [0.11641299, 0.11543185, 0.11311269, 0.10970636, 0.09623121],
#        [0.13698066, 0.14081048, 0.11185589, 0.11582382, 0.22450144],
#        [0.12052653, 0.11829718, 0.11311269, 0.10929853, 0.09303586],
#        [0.11024269, 0.10601719, 0.09426058, 0.09339315, 0.1096973 ],
#        [0.05265323, 0.04911993, 0.04985337, 0.04812398, 0.04784457],
#        [0.04853969, 0.05075727, 0.04985337, 0.05016313, 0.06717355],
#        [0.05059646, 0.04952927, 0.05194805, 0.05057096, 0.03733132],
#        [0.05059646, 0.04830127, 0.05027231, 0.04934747, 0.06132493],
#        [0.05018511, 0.0474826 , 0.04985337, 0.04893964, 0.03684631],
#        [0.05018511, 0.05034793, 0.04943444, 0.04812398, 0.05686   ],
#        [0.0431921 , 0.03929595, 0.0372853 , 0.04078303, 0.2046304 ],
#        [0.04072398, 0.04338928, 0.03979891, 0.04486134, 0.09299307],
#        [0.04607157, 0.04461727, 0.04189359, 0.04526917, 0.0719095 ],
#        [0.04442616, 0.04257061, 0.04398827, 0.04323002, 0.03663234],
#        [0.04236939, 0.04011461, 0.04398827, 0.04282219, 0.03283786],
#        [0.04236939, 0.04257061, 0.04021785, 0.04078303, 0.05310833],
#        [0.04195804, 0.03847728, 0.04105572, 0.0403752 , 0.04138256],
#        [0.04195804, 0.03888661, 0.04063678, 0.04078303, 0.0369319 ],
#        [0.04031263, 0.03929595, 0.04063678, 0.03996737, 0.037745  ],
#        [0.04113533, 0.03724928, 0.0385421 , 0.03792822, 0.05082594],
#        [0.03784451, 0.03561195, 0.03770423, 0.03915171, 0.0593421 ],
#        [0.03948992, 0.03643062, 0.04063678, 0.03955954, 0.01838749],
#        [0.04031263, 0.03683995, 0.03812317, 0.03670473, 0.03932841],
#        [0.03784451, 0.03520262, 0.03602849, 0.0362969 , 0.05531939],
#        [0.0431921 , 0.03929595, 0.03937997, 0.03955954, 0.06001255],
#        [0.04072398, 0.03683995, 0.03686636, 0.0362969 , 0.10543208],
#        [0.0370218 , 0.03602129, 0.03644742, 0.03915171, 0.09717269],
#        [0.03825586, 0.0462546 , 0.03937997, 0.04649266, 0.20829648],
#        [0.04812834, 0.05321326, 0.04775869, 0.05424144, 0.17075119],
#        [0.05717811, 0.05321326, 0.04985337, 0.05097879, 0.06122507],
#        [0.05183052, 0.05075727, 0.05236699, 0.05301794, 0.04513423],
#        [0.05388729, 0.05648792, 0.05529954, 0.05954323, 0.14748509],
#        [0.06005759, 0.06099059, 0.05571848, 0.06158238, 0.13983909],
#        [0.06046894, 0.06017192, 0.05781315, 0.05668842, 0.07995492],
#        [0.0555327 , 0.05485059, 0.05278592, 0.05220228, 0.08220878],
#        [0.05306458, 0.04952927, 0.04859656, 0.04893964, 0.08397763],
#        [0.0493624 , 0.0462546 , 0.04733976, 0.04893964, 0.09770049],
#        [0.05059646, 0.05689726, 0.05152912, 0.05831974, 0.17577245],
#        [0.05882353, 0.05525993, 0.05613741, 0.0550571 , 0.05720236],
#        [0.05594405, 0.05198526, 0.0536238 , 0.05179445, 0.04798722],
#        [0.05183052, 0.0523946 , 0.05278592, 0.05342577, 0.05392143],
#        [0.05347593, 0.05157593, 0.0548806 , 0.05301794, 0.01733189],
#        [0.05265323, 0.0499386 , 0.05111018, 0.04893964, 0.04872899],
#        [0.04853969, 0.04666394, 0.04943444, 0.04893964, 0.03904311],
#        [0.05018511, 0.0474826 , 0.05027231, 0.04934747, 0.02971385],
#        [0.0493624 , 0.05075727, 0.05069124, 0.05220228, 0.06790106],
#        [0.05470999, 0.05198526, 0.05446167, 0.05464927, 0.0464894 ],
#        [0.05676676, 0.05280393, 0.0536238 , 0.05342577, 0.03917149],
#        [0.05347593, 0.05607859, 0.05446167, 0.05831974, 0.08202334],
#        [0.05882353, 0.06590258, 0.06074571, 0.06810767, 0.15316253],
#        [0.06951871, 0.06876791, 0.06577294, 0.06973899, 0.16187841],
#        [0.07034142, 0.09496521, 0.07038123, 0.09584013, 0.53597615],
#        [0.09214315, 0.11011052, 0.09049016, 0.11215334, 0.39358364],
#        [0.12052653, 0.12689316, 0.1085044 , 0.11908646, 0.41392542],
#        [0.123406  , 0.13385182, 0.11939673, 0.13254486, 0.28508459],
#        [0.13286713, 0.13999181, 0.13405949, 0.13539967, 0.13861231],
#        [0.13656931, 0.13671715, 0.12107248, 0.12601958, 0.21802516],
#        [0.12093788, 0.1273025 , 0.12400503, 0.12479608, 0.07647428],
#        [0.12422871, 0.12648383, 0.11101801, 0.12438825, 0.16883969],
#        [0.12464006, 0.1473598 , 0.12609971, 0.1411093 , 0.22495792],
#        [0.14479637, 0.14121981, 0.13154587, 0.12724307, 0.09454794],
#        [0.12916495, 0.13426115, 0.12526183, 0.1223491 , 0.09955493],
#        [0.12176059, 0.12975849, 0.11939673, 0.12153344, 0.10005421],
#        [0.12258329, 0.12443717, 0.12442396, 0.12520392, 0.02516333],
#        [0.12875359, 0.1273025 , 0.12735651, 0.12479608, 0.05346495],
#        [0.12422871, 0.12116251, 0.11185589, 0.11256117, 0.10110981],
#        [0.11229946, 0.10888252, 0.10138249, 0.11052202, 0.06733046],
#        [0.10983134, 0.10724519, 0.09635526, 0.09380098, 0.09534678],
#        [0.09378856, 0.09455587, 0.09300377, 0.09094617, 0.0727654 ],
#        [0.10407239, 0.13098649, 0.10473398, 0.11704731, 0.27479958],
#        [0.11929247, 0.12320917, 0.11353163, 0.11052202, 0.09152378],
#        [0.11147675, 0.10888252, 0.11018014, 0.11011419, 0.05452056],
#        [0.1110654 , 0.10765452, 0.10180142, 0.0995106 , 0.04521982],
#        [0.09995886, 0.10397053, 0.10180142, 0.10032626, 0.05380731],
#        [0.10201563, 0.10274253, 0.1026393 , 0.0995106 , 0.04094034],
#        [0.09995886, 0.0986492 , 0.10180142, 0.0995106 , 0.03151123],
#        [0.09995886, 0.10151453, 0.1026393 , 0.10358891, 0.03479216],
#        [0.10407239, 0.1035612 , 0.10222036, 0.10318108, 0.02703204],
#        [0.10530645, 0.10151453, 0.1026393 , 0.10032626, 0.01835896],
#        [0.10612916, 0.13548915, 0.10892333, 0.13743883, 0.20923797],
#        [0.13656931, 0.13303316, 0.12065354, 0.1223491 , 0.08621723],
#        [0.11641299, 0.11543185, 0.11311269, 0.10970636, 0.09623121],
#        [0.13698066, 0.14081048, 0.11185589, 0.11582382, 0.22450144],
#        [0.12052653, 0.11829718, 0.11311269, 0.10929853, 0.09303586],
#        [0.11024269, 0.10601719, 0.09426058, 0.09339315, 0.1096973 ]])

# %%
x_test = []
y_test = []

for i in range(60, inputs.shape[0]):
    x_test.append(inputs[i - 60: i])
    y_test.append(inputs[i, 0])

x_test = np.array(x_test)    
y_test = np.array(y_test)
x_test.shape, y_test.shape
# Out:
# ((81, 60, 5), (81,))

# %%
x_test.shape
# Out:
# (81, 60, 5)

# %%
y_pred = regressor.predict(x_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 5) for input Tensor("lstm_8_input:0", shape=(None, 100, 5), dtype=float32), but it was called on an input with incompatible shape (None, 60, 5).

# %%
scaler.scale_
# Out:
# array([4.11353336e-02, 4.09332788e-02, 4.18935903e-02, 4.07830343e-02,
#        1.42649282e-07])

# %%
scale = 1 / 4.11353336e-02
scale
# Out:
# 24.31000097687308

# %%
y_pred = y_pred * scale
y_test = y_test * scale

# %%
y_pred.shape
# Out:
# (81, 1)

# %%
y_test.shape
# Out:
# (81,)

# %%
y_pred[40:]
# Out:
# array([[1.9360833],
#        [1.9220078],
#        [1.9232605],
#        [1.9422415],
#        [1.9660524],
#        [2.000238 ],
#        [2.0687673],
#        [2.1586077],
#        [2.2228365],
#        [2.3317323],
#        [2.3913903],
#        [2.456459 ],
#        [2.5304282],
#        [2.566548 ],
#        [2.617141 ],
#        [2.6791675],
#        [2.7891064],
#        [2.9156814],
#        [3.006527 ],
#        [3.0374634],
#        [3.071845 ],
#        [3.129417 ],
#        [3.1585543],
#        [3.1436436],
#        [3.0768619],
#        [2.972117 ],
#        [2.9898777],
#        [3.0379608],
#        [3.047829 ],
#        [3.0005505],
#        [2.9490466],
#        [2.9209886],
#        [2.9033823],
#        [2.9059503],
#        [2.9257305],
#        [2.9507096],
#        [3.0468724],
#        [3.1879768],
#        [3.2521913],
#        [3.240787 ],
#        [3.1832132]], dtype=float32)

# %%
y_test[40:]
# Out:
# array([1.22, 1.2 , 1.33, 1.38, 1.3 , 1.43, 1.69, 1.71, 2.24, 2.93, 3.  ,
#        3.23, 3.32, 2.94, 3.02, 3.03, 3.52, 3.14, 2.96, 2.98, 3.13, 3.02,
#        2.73, 2.67, 2.28, 2.53, 2.9 , 2.71, 2.7 , 2.43, 2.48, 2.43, 2.43,
#        2.53, 2.56, 2.58, 3.32, 2.83, 3.33, 2.93, 2.68])

# %%
plt.figure(figsize = (14,5))
plt.plot(y_test, color = 'red', label = 'Real Nautilus Stock Price')
plt.plot(y_pred, color = 'blue', label = 'Predicted Nautilus Stock price')
plt.title('Nautilus Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Nautilus Stock Price')
plt.legend()
plt.show()
